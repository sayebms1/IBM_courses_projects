# %% [markdown]
# # Election markers for Gainesville (Blue county) and neightboring red county

# %% [markdown]
# The purpose of this project is to provide an anlysis of two different counties that have voted democrat or republican in the 2020 election. This analysis is based on many factors one of them being the venues and the qualitative studyof these venues as markers of election outcome for a county. Our presumption is that there is less diversity in the venues for the red counties.

# %% [markdown]
# ## 1- County population

# %%
import pandas as pd

# %%
url = "https://www2.census.gov/programs-surveys/popest/datasets/2010-2019/counties/totals/co-est2019-alldata.csv"
county_pop = pd.read_csv(url,encoding='latin-1')

# %%
county_pop = county_pop[county_pop['STNAME']=='Florida']
county_pop.reset_index(drop=True, inplace=True)
county_pop.head()
# Out:
#    SUMLEV  REGION  DIVISION  STATE  COUNTY   STNAME          CTYNAME  \
# 0      40       3         5     12       0  Florida          Florida
# 1      50       3         5     12       1  Florida   Alachua County
# 2      50       3         5     12       3  Florida     Baker County
# 3      50       3         5     12       5  Florida       Bay County
# 4      50       3         5     12       7  Florida  Bradford County
#
#    CENSUS2010POP  ESTIMATESBASE2010  POPESTIMATE2010  ...  RDOMESTICMIG2019  \
# 0       18801310           18804564         18845537  ...          6.268893
# 1         247336             247337           247614  ...         -4.841103
# 2          27115              27115            27066  ...         27.865122
# 3         168852             168850           169206  ...        -66.935406
# 4          28520              28519            28536  ...         18.122353
#
#    RNETMIG2011  RNETMIG2012  RNETMIG2013  RNETMIG2014  RNETMIG2015  \
# ...

# %%
col_not_2019=[col for col in county_pop.columns if '2019' not in col]
county_pop.drop(columns = col_not_2019, inplace=True )

# %%
county_pop.head()
# Out:
#    POPESTIMATE2019  NPOPCHG_2019  BIRTHS2019  DEATHS2019  NATURALINC2019  \
# 0         21477737        233420      221695      211692           10003
# 1           269043           192        2775        2081             694
# 2            29210           857         322         273              49
# 3           174705        -11535        2222        1989             233
# 4            28201           449         285         349             -64
#
#    INTERNATIONALMIG2019  DOMESTICMIG2019  NETMIG2019  RESIDUAL2019  \
# 0                 88678           133910      222588           829
# 1                   798            -1302        -504             2
# 2                     5              802         807             1
# 3                   277           -12080      -11803            35
# 4                     2              507         509             4
#
#    GQESTIMATES2019  RBIRTH2019  RDEATH2019  RNATURALINC2019  \
# ...
